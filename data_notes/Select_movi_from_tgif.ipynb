# %% [markdown]
# dataset - https://github.com/raingo/TGIF-Release/tree/master

# %%
# Load dataset
# !git clone https://github.com/raingo/TGIF-Release.git -q

#Load project
# !git clone https://github.com/Mike030668/Rotation_T2I_to_T2V.git -q

# %%
import sys
dir_project = '/content/Rotation_T2I_to_T2V'
sys.path.append(dir_project)

# %% [markdown]
# # Random view

# %%
import os
import pandas as pd
import random
from data.tgif.tgif_data import TakeTgif

data_path = '/content/TGIF-Release/data/tgif-v1.0.tsv'
gif_df = pd.read_csv(data_path, sep='\t', header=None)
gif_df.sample(10), gif_df.shape
# Out:
# (                                                        0  \
#  60985   https://38.media.tumblr.com/0f3a981877903c3123...
#  121462  https://38.media.tumblr.com/c561df6ce7725d3390...
#  15369   https://33.media.tumblr.com/15535a8101e14c10d2...
#  71973   https://31.media.tumblr.com/968ae14be8e886d650...
#  53577   https://31.media.tumblr.com/386beabe7eadd20507...
#  13557   https://33.media.tumblr.com/fa5f90be55c1003c29...
#  26074   https://38.media.tumblr.com/181bcf7ee0049566fd...
#  116347  https://33.media.tumblr.com/a2c449fc5ad4853519...
#  106437  https://38.media.tumblr.com/08cc4566950da7b2fd...
#  32563   https://33.media.tumblr.com/31002e90dbaf1c6b4a...
#
#                                                          1
#  60985   two men are talking and laughing with each other.
#  121462         a group of guys is talking around a table.
#  15369   an asian girl wearing a pink bow pulls a funny...
#  71973      a man wearing black and brown turned his head.
#  53577             a woman holds a man and dances with him
#  13557            a man is riding a skateboard on a house.
#  26074   two siblings show love while eating food toget...
#  116347  a lady is crouched down and she slowly looking...
#  106437  a guy gets a cup of coffee knocked out of his ...
#  32563   an asian man shows his judo skills with a kick...  ,
#  (125782, 2))

# %%
from IPython.display import Image
gif_idx = gif_df.sample().index[0] #rand id

caption_original = gif_df[1][gif_idx]
print(f'caption_original of {gif_idx} gif: {caption_original}\n')
url = gif_df[0][gif_idx]
print(f'url = {url}\n')
Image(url=url)  # external
# Out:
# caption_original of 94037 gif: a cat throws a blanket over another cat and they play fight.
#
# url = https://31.media.tumblr.com/554c5681a1760f5eb947152c81813c41/tumblr_npgljp2eVF1tiwqiyo1_400.gif
# <img src="https://31.media.tumblr.com/554c5681a1760f5eb947152c81813c41/tumblr_npgljp2eVF1tiwqiyo1_400.gif"/>

# %% [markdown]
# ## Seach videos with specific captions
#
# (for examples in papers and presentations only)

# %%
tsv_path = "/content/TGIF-Release/data/tgif-v1.0.tsv"
txt_path = "/content/TGIF-Release/data/splits/train.txt"

maker = TakeTgif(tsv_path, txt_path)

# %%
maker.selector(patterns_to_search = ["microphone",  "dance"])
maker.matchs
# Out:
# [(1562, "a man sing's and dances in front of a microphone"),
#  (2337, 'a woman dances around while is holding a microphone.'),
#  (5646, 'a woman dances and whip her hair in front of a microphone.'),
#  (6938,
#   'a young man speaks into a microphone as a giant bird head dances behind him.'),
#  (7041,
#   'a man in a white sports coat sings into the microphone while two men dance behind him'),
#  (9170, 'a woman wearing a microphone headset does a dance move'),
#  (10099, 'a man sings and dances in front of a microphone'),
#  (11473, 'a man sings into a microphone and dances on stage'),
#  (19252, 'a woman dances on stage and holds a microphone.'),
#  (22561, 'a few boys dance and sing into microphones.'),
#  (24349, 'a young female sings and dances with a microphone.'),
#  (25134,
#   'a woman sings into a microphone with a man and woman on either side smile and bop around some dance movement.'),
#  (25443, 'two men with microphone are doing some dance moves'),
#  (26677, 'this is a man doing a silly dance holding a microphone.'),
#  (30124, 'a man is wearing a red hat and holding a microphone and he dances'),
#  (31676, 'there is a man spinning a microphone in his hand as he dances.'),
#  (31797, 'men with microphones bend down to dance.'),
#  (33248, 'a man sings with a microphone and dances.'),
#  (33265, 'a man sings into his microphone and dances'),
#  (34064,
#   'a black woman with an orange jacket dances and sings into a microphone.'),
#  (34819, "a lady in a blue top sing's into a microphone when two men dance"),
#  (34979, 'a man holds a microphone while another dances.'),
#  (36813, 'two men dance while one of them sings into a microphone.'),
#  (37487, 'a woman holding a microphone dances and shakes her chest.'),
#  (37897, 'a man with a microphone is doing a dorky dance.'),
#  (39450, 'a man dances and sings into a microphone on stage'),
#  (39578,
#   'a man, wearing a headband and holding a microphone, dances from side to side.'),
#  (40815,
#   'a woman in a plaid skirt is singing into a microphone while someone dances in front of her'),
#  (42332, 'a girl dances and sings with a pretend microphone.'),
#  (42499,
#   'a man wearing back dances from side to side while singing in a microphone'),
#  (43250,
#   'a girl dances from side to side while singing on a microphone in front of two other girls'),
#  (43604,
#   'a man dressed in black dances with a microphone stand while he sings into a microphone'),
#  (47328,
#   'a singer stands on a speaker and dances, twirling his microphone in the air'),
#  (49050,
#   'one man sits and dances on a couch while the other speaks into a microphone.'),
#  (50168, 'a performer wearing a microphone performed an emotional dance.'),
#  (52332, 'a man danced in front of a microphone on a purple background.'),
#  (60348, 'a group of girls dance behind a girl with a microphone.'),
#  (63990, 'a man in a red hat dances and sings into a microphone.'),
#  (64368, 'a young man with a microphone smiles and dances.'),
#  (66320,
#   'a bunch of men in street clothing dance around and sing with microphones'),
#  (67611,
#   'a man dances, holding a microphone, while fireworks go off behind him.'),
#  (67970, 'a woman on stage dances happily and sings into the microphone'),
#  (71020, 'a person holds their microphone up and dances.'),
#  (72198, 'a man dances and sings into the microphone.'),
#  (74765, 'woman dances with and around microphone stand seductively.'),
#  (75078, 'a man on stage is speaking into the microphone and dances'),
#  (75521, 'two men sing into microphones and dance on a stage'),
#  (78763, 'a tattooed man with a microphone performs a dance.'),
#  (78777, 'a woman dances on a stage and sings to her microphone.'),
#  (79089, 'a man is singing into a microphone as other men dance behind him.'),
#  (81357, 'a man is singing into a microphone whilst others dance behind him'),
#  (82726,
#   'a white man sings into a microphone while women dance in the background.'),
#  (83151,
#   'a performer snaps her fingers and dances while singing at a microphone stand.'),
#  (86372,
#   'a man smiles and dances while he sits in front of a studio microphone.'),
#  (87147, 'a girl lowers a microphone as other girls dance around her.'),
#  (91350, 'a woman dances and sings into a microphone.'),
#  (91970, 'a performer sways his hips and dances while holding a microphone.'),
#  (99961,
#   'a girl in a white skirt is dancing with a microphone in front of a male dancer.'),
#  (100689, 'boy dances and sings into the microphone in front of a crowd'),
#  (102608, 'a man holding a microphone performs a dance.'),
#  (112522, 'a man in a suit holds a microphone and dances')]

# %% [markdown]
# ## Seach random videos

# %%
maker.selector(qty=100, patterns_to_search = "random")
matchs = maker.matchs
matchs
# Out:
# [(70657, 'a person in a costume looks back and forth.'),
#  (75058, 'a man in a suit makes a weird face.'),
#  (49495, 'a man moves his hand up to his face.'),
#  (40042, 'a man jumps and makes hand motions.'),
#  (51969, 'two slices of toast are popping out of a toaster.'),
#  (22753, 'a woman in a dress is spinning around in circles'),
#  (18871, 'a baby is crying after a toy pops up out of a box.'),
#  (71230,
#   'a woman is walking with 4 coffee cups and then sets one down on a table.'),
#  (94480, 'a red lip long hair girl is showing her pictures in power point'),
#  (52304, 'a man let his shirt ups, and walks.'),
#  (85251, 'two men are hugging on a red floor.'),
#  (2547, 'a woman wearing a cat costume poses and leans forward'),
#  (62818, 'a chemical thing happens when the element is boiled'),
#  (3773, 'a cat hidden under a small black box.'),
#  (86375, 'a cat is pawing and scratching while laying down.'),
#  (68781, 'two men are hugging in a field.'),
#  (85718, 'a boy is singing with a microphone in his hand'),
#  (1852, 'a man takes the hand of another person and kisses it.'),
#  (63142, 'a person with short hair is talking and smiling.'),
#  (55630, 'a person running across a road is hit by a car.'),
#  (39691, 'two young men are sat closely together and talking.'),
#  (78269, 'a man is jumping into a crowd of other men.'),
#  (53642, 'a girl are turning and smiling and looking back'),
#  (65464, 'the man is putting a shirt on over his shoulder'),
#  (81262, 'a man is looking suspicious and drinking from cup'),
#  (88153, 'A man in a mask is being fed jell'),
#  (21885,
#   'a woman with dark hair is laughing and fanning her face with her hands.'),
#  (32864, 'a warrior rips the guts out of another man.'),
#  (92893, 'a woman places a small pumpkin beside another big'),
#  (69164,
#   'two men are bursting through a door and shooting people in a corridor'),
#  (52666, 'a woman makes a scary gesture and growls.'),
#  (96127, 'a little boy accidentally hits a baby with a baseball bat.'),
#  (10362, 'a long haired man runs his tongue along a red popsicle'),
#  (9788, 'two men are doing movements with their hands.'),
#  (33870, 'several young people are skateboarding on a bridge'),
#  (66281, 'that young woman with pink hair is looking down to hair'),
#  (10376, 'there is a guy walking and pulling up his shirt sleeve'),
#  (88432, 'a man is dancing by hopping and kicking and scuffling around.'),
#  (90260, 'a girl sits on a cement floor beside a big truck wheel'),
#  (54866,
#   'a polar bear throws something into the water then jumps in after it.'),
#  (100524, 'a girl wearing glasses is smiling and waving'),
#  (94772, 'two people in pink shirts are sitting in an audience and clapping.'),
#  (70032, 'a man and a woman are dancing with each other.'),
#  (58346, 'the man walks through a bush to toss a box.'),
#  (96239, 'a boy with blonde hair is screaming at a girl and she is scared'),
#  (52343, 'a girl smiles at another girl with a bow.'),
#  (19532, 'a person is playing with a little dog and the dog licks her'),
#  (104998, 'a beautiful woman is opening her eyes.'),
#  (87375, 'a black and white dog is sliding down a hill on his back.'),
#  (14286, 'a dark-haired man talks to someone and looks surprised'),
#  (73711,
#   "one kid bites the other one's hair and the second kid makes a face expression"),
#  (46097, 'a cat is climbing up the front of a fridge'),
#  (3047,
#   'a man in a white shirt is approached by another man who kisses him on the cheek and goes away again'),
#  (40542, 'a man is in chair and smiling.'),
#  (53408, 'a group of men are doing a synchronized dance.'),
#  (59022, 'a young man and girl are kissing and embracing on a bed'),
#  (54709, 'the cute little dog is digging on the couch.'),
#  (44204, 'this is a football match and a footballer scoring a goal.'),
#  (52549, 'a man with long hair sits in various places.'),
#  (51267, 'a white man wearing a hat is greeting through a hole'),
#  (82325, 'a naked man with a beard is singing.'),
#  (17721, 'a man trips on a run and drops a bowl of popcorn.'),
#  (95600, 'a bunch of race cars are driving down the track together.'),
#  (15891, 'banana pancakes with chocolate sauce are sprinkled with sugar'),
#  (22261, 'the snow boarder is jumping over the ramp'),
#  (63824, 'a handsome man is talking to a beautiful woman'),
#  (9485, 'a man squints his eyes and looks away.'),
#  (75101, 'a man on a skateboard is bouncing off a wall.'),
#  (29682, "a cat is clawing somebody's hair."),
#  (75268, 'a young man is dancing in a spotlight.'),
#  (91613, 'a girl is looking at something and smiling.'),
#  (61452, 'two boys with microphones and one with a guitar sit on a stage.'),
#  (84359, 'two men are sitting on furniture and looking at each other'),
#  (1415, 'a man wearing a red tee shirt is playing drums.'),
#  (23389, 'a man and woman share a joke together.'),
#  (40505, 'this is a dog getting wet in a bathtub.'),
#  (2219, 'a guy is singing a song on a stage.'),
#  (49148, 'a group of males are dancing in synchronization.'),
#  (13644, 'a guy on stage pointed towards the audience'),
#  (36943, 'a woman trips over toys on the floor and breaks a coffee table.'),
#  (9002, 'a woman is skipping through the water at a beach.'),
#  (32089, 'a couple are holding each other in a very tight hug.'),
#  (3433, 'this guy is riding a bike and doing tricks.'),
#  (7839, 'a woman posing for a picture falls forward.'),
#  (10438, 'a man wearing a jumper is talking to someone'),
#  (29409, 'a dog in a cardboard police car is chasing another dog.'),
#  (19594, 'a bunch of white birds are escaping from a trailer.'),
#  (10703, 'a man is moving his head in the air aggressively'),
#  (32188, 'two men are sitting on the edge of stage relaxing.'),
#  (50672, 'a man wearing a suit is rolling his tongue and making faces.'),
#  (59738, "a man waves a piece of paper to make a man's hair move"),
#  (41592, 'a man is running and then jumps with others.'),
#  (54735, 'a male lifts up his shirt to reveal toned abs.'),
#  (6270, 'a person stands on a large pink ball and falls into the wall'),
#  (19756, 'a man is dancing around his kitchen while another guy looks'),
#  (78333, 'a group of men wearing white t shirts heads ahead.'),
#  (38103, 'a penguin loses its footing and falls off the cliff.'),
#  (48103,
#   'a man in a suit and bow tie stands, turns his head to the right and smiles'),
#  (67806, 'a woman speaks and then turns her head.'),
#  (7084, 'two men are sat on a couch talking to each other')]

# %%
id_choice = random.randint(0, len(matchs))
idx = matchs[id_choice][0]

caption = maker.train_df.loc[idx][1]
print(f'caption_original of {idx} gif: {caption}\n')
url =  maker.train_df.loc[idx][0]
Image(url=url)  # external
# Out:
# caption_original of 49495 gif: a man moves his hand up to his face.
# <img src="https://31.media.tumblr.com/7dfeb706434f85449833682188959314/tumblr_nfpfwyTTH81u4b4a0o1_250.gif"/>

# %% [markdown]
# # bad movi can be

# %% [markdown]
# ### It's sample of bad gif with several statc frames

# %%
idx = 43250
caption = maker.train_df.loc[idx][1]
print(f'caption_original of {idx} gif: {caption}\n')
url =  maker.train_df.loc[idx][0]
Image(url=url)  # external
# Out:
# caption_original of 43250 gif: a girl dances from side to side while singing on a microphone in front of two other girls
# <img src="https://33.media.tumblr.com/415a5b5e29ae347c8db1e122e520da99/tumblr_nb5m7lKmXE1tey9v1o1_500.gif"/>

# %% [markdown]
# # Prepare dataset
#
# Becase we take from old GIF dataset, it have short, static and low resolution movis.
#
# We have to select more good movies!

# %%
# what separete
LEN_MOVI = 100
wait_movis = 500
MIN_SIZE = 600
take_min = 15 # q_ty take frame from gif

path_to = "/content/drive/Othercomputers/My_comp/Документы/МФТИ_Наука_о_данных/Diplom_project/Rotation_T2I_to_T2V/data"
file_path = path_to + "/tgif" f"/movies_info_more_{MIN_SIZE}pxls.csv"

# %%
maker.selector(patterns_to_search = "random")

maker.seacher(min_size = MIN_SIZE,
              take_min = take_min,
              wait_len = LEN_MOVI,
              wait_movis = wait_movis,
              file_path = file_path
)
# Out:
# Movi 1670 have len = 17 take all move with W_675 x H_785 selected_1
#
# Movi 5194 have len = 33 take all move with W_795 x H_840 selected_2
#
# Movi 6882 have len = 16 take all move with W_800 x H_717 selected_3
#
# Movi 7187 have len = 30 take all move with W_607 x H_606 selected_4
#
# Movi 14155 have len = 22 take all move with W_606 x H_808 selected_5
#
# Movi 14743 have len = 29 take all move with W_640 x H_640 selected_6
#
# Movi 14835 have len = 20 take all move with W_640 x H_640 selected_7
#
# Movi 15383 have len = 19 take all move with W_640 x H_640 selected_8
#
# Movi 16077 have len = 23 take all move with W_720 x H_1080 selected_9
#
# Movi 16379 have len = 17 take all move with W_768 x H_1024 selected_10
#
# Movi 16380 have len = 17 take all move with W_768 x H_1024 selected_11
#
# Movi 16688 have len = 16 take all move with W_720 x H_1280 selected_12
#
# Movi 17503 have len = 25 take all move with W_638 x H_638 selected_13
#
# Movi 17851 have len = 18 take all move with W_1280 x H_720 selected_14
#
# Movi 18168 have len = 46 take all move with W_720 x H_720 selected_15
#
# Movi 18169 have len = 46 take all move with W_720 x H_720 selected_16
#
# Movi 18418 have len = 20 take all move with W_720 x H_1280 selected_17
#
# Movi 19915 have len = 31 take all move with W_640 x H_640 selected_18
#
# Movi 21020 have len = 17 take all move with W_640 x H_640 selected_19
#
# Movi 21533 have len = 76 take all move with W_640 x H_640 selected_20
#
# Movi 21711 have len = 43 take all move with W_600 x H_600 selected_21
#
# Movi 22311 have len = 16 take all move with W_640 x H_640 selected_22
#
# Movi 26535 have len = 20 take all move with W_640 x H_640 selected_23
#
# Movi 43407 have len = 25 take all move with W_640 x H_640 selected_24
#
# Movi 44166 have len = 46 take all move with W_640 x H_640 selected_25
#
# Movi 52619 have len = 20 take all move with W_1000 x H_667 selected_26
#
# Movi 53448 have len = 101 take all move with W_1280 x H_688 selected_27
#
# Movi 57215 have len = 20 take all move with W_600 x H_800 selected_28
#
# Movi 61125 have len = 98 take all move with W_640 x H_640 selected_29
#
# Movi 64954 have len = 24 take all move with W_606 x H_808 selected_30
#
# Movi 69036 have len = 18 take all move with W_1000 x H_715 selected_31
#
# Movi 89925 have len = 24 take all move with W_1280 x H_720 selected_32
#
# Movi 125406 have low H or W
